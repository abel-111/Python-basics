# %%
#circle radius
a=float(input("Enter the radius of the circle: "))
b=3.14*a*a
print("Area of a circle is: ",b)
# Out:
# Enter the radius of the circle: 3
# Area of a circle is:  28.259999999999998

# %%
#2nd q
a=input("Enter the name of student: ")
b=int(input("Enter the age of student: "))
c=input("mark of student: ")
print("Name: "+a)
print("Roll no: ",b)
print("mark: ",c)
# Out:
# Enter the name of student: Abel
# Enter the age of student: 20
# mark of student: 100
# Name: Abel
# Roll no:  20
# mark:  100

# %%
#3rd
a=[12,3,47,10]
max1=a[0]
for i in a:
  if i>max1:
    max1=i
print(max1)
# Out:
# 47

# %%
#4
for i in range(1,11):
  current_no=i
  previous=i-1
  c=current_no+previous
  print("current no ",current_no,"previous no ",previous,"sum ",c)
# Out:
# current no  1 previous no  0 sum  1
# current no  2 previous no  1 sum  3
# current no  3 previous no  2 sum  5
# current no  4 previous no  3 sum  7
# current no  5 previous no  4 sum  9
# current no  6 previous no  5 sum  11
# current no  7 previous no  6 sum  13
# current no  8 previous no  7 sum  15
# current no  9 previous no  8 sum  17
# current no  10 previous no  9 sum  19

# %%
#5
x=[10,20,33,46,55]
for i in x:
  if i%5==0:
    print(i)
# Out:
# 10
# 20
# 55

# %%
#6
x=int(input("Enter a number: "))
flag=1
if x<=1:
  flag=0
else:
  for i in range(2,x):
    if x%i==0:
      flag=0
if flag==1:
  print(x," is a prime nmber")
else:
  print(x," is not a prime number")
# Out:
# Enter a number: 1
# 1  is not a prime number

# %%
#7
l1=[10,40,30,70]
l2=[]
for i in range(-1,-5,-1):
  l2.append(l1[i])
print(l2)
# Out:
# [70, 30, 40, 10]

# %%
#8
for i in range(1,5):
  print("*"*i)
# Out:
# *
# **
# ***
# ****

# %%
#9
a=int(input('Enter 1st no: '))
b=int(input('Enter 2nd no: '))
c=int(input('Enter 3rd no: '))
if a>b and a>c:
  print(a,' is big')
elif b>a and b>c:
  print(b," is big")
else:
  print(c," is big")
# Out:
# Enter 1st no: 34
# Enter 2nd no: 12
# Enter 3rd no: 7
# 34.0  is big

# %%
for i in range(1,6):
  for j in range(i):
    print("*",end="")
  print()

for i in range(4,0,-1):
  for j in range(i):
    print("*",end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
